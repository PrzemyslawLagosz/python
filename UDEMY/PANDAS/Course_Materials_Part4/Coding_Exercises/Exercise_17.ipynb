# %% [markdown]
# # Coding Exercises (Part 4)

# %% [markdown]
# ## Time Series Data

# %% [markdown]
# ### Exercise 17: Financial Time Series

# %% [markdown]
# Now, you will have the opportunity to analyze your own dataset. <br>
# __Follow the instructions__ and insert your code! You are either requested to
# - Complete the Code and __Fill in the gaps__. Gaps are marked with "__---__" and are __placeholders__ for your code fragment.
# - Write Code completely __on your own__

# %% [markdown]
# In some exercises, you will find questions that can only be answered, if your code is correct and returns the right output! The correct answer is provided below your coding cell. There you can check whether your code is correct.

# %% [markdown]
# If you need a hint, check the __Hints Section__ at the end of this Notebook. Exercises and Hints are numerated accordingly.

# %% [markdown]
# If you need some further help or if you want to check your code, you can also check the __solutions notebook__.

# %% [markdown]
# ### Have Fun!

# %% [markdown]
# --------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Option 1: Self_guided

# %% [markdown]
# Import the us stocks dataset (__us_stocks.csv__) and select the Adjusted Close (__Adj Close__) for all six stocks from __31-12-2015__ (incl.) until __31-12-2018__ (incl.). Save the DataFrame in the variable __stocks__ and work through the next questions with this DataFrame!

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
stocks = pd.read_csv("us_stocks.csv", header=[0,1], index_col= [0], parse_dates= [0])
stocks.head()
# Out:
#                  Open                                                  \
#                   AXP  FB       INTC        MCD         PG        WMT
# Date
# 2009-12-31  40.900002 NaN  20.600000  62.970001  61.520000  54.250000
# 2010-01-04  40.810001 NaN  20.790001  62.630001  61.110001  53.740002
# 2010-01-05  40.830002 NaN  20.940001  62.660000  61.130001  54.090000
# 2010-01-06  41.230000 NaN  20.809999  62.200001  60.939999  53.500000
# 2010-01-07  41.259998 NaN  20.730000  61.250000  60.580002  53.720001
#
#                  High                        ...  Adj Close             \
#                   AXP  FB       INTC    MCD  ...       INTC        MCD
# Date                                         ...
# 2009-12-31  41.080002 NaN  20.719999  63.07  ...  15.252899  47.055138
# 2010-01-04  41.099998 NaN  21.030001  63.07  ...  15.611791  47.311375
# 2010-01-05  41.230000 NaN  20.990000  62.75  ...  15.604316  46.949627
# 2010-01-06  41.669998 NaN  20.930000  62.41  ...  15.551979  46.309067
# 2010-01-07  42.240002 NaN  20.760000  62.34  ...  15.402434  46.648193
#
#                                     Volume                                   \
#                    PG        WMT       AXP  FB      INTC       MCD       PG
# Date
# 2009-12-31  45.146072  42.548668   4030500 NaN  26429200   4495300  5942200
# 2010-01-04  45.510941  43.169579   6894300 NaN  47800900   5839300  9190800
# 2010-01-05  45.525822  42.739723  10641200 NaN  52357700   7099000  8649400
# 2010-01-06  45.309883  42.644184   8399400 NaN  40037400  10551300  9908400
# 2010-01-07  45.064171  42.668079   8981700 NaN  54041500   7517700  8972800
#
#
#                  WMT
# Date
# 2009-12-31   9764800
# 2010-01-04  20753100
# 2010-01-05  15648400
# 2010-01-06  12517200
# 2010-01-07  10662700
#
# [5 rows x 36 columns]

# %%
stocks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2264 entries, 2009-12-31 to 2018-12-28
# Data columns (total 36 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   (Open, AXP)        2264 non-null   float64
#  1   (Open, FB)         1664 non-null   float64
#  2   (Open, INTC)       2264 non-null   float64
#  3   (Open, MCD)        2264 non-null   float64
#  4   (Open, PG)         2264 non-null   float64
#  5   (Open, WMT)        2264 non-null   float64
#  6   (High, AXP)        2264 non-null   float64
#  7   (High, FB)         1664 non-null   float64
#  8   (High, INTC)       2264 non-null   float64
#  9   (High, MCD)        2264 non-null   float64
#  10  (High, PG)         2264 non-null   float64
#  11  (High, WMT)        2264 non-null   float64
#  12  (Low, AXP)         2264 non-null   float64
#  13  (Low, FB)          1664 non-null   float64
#  14  (Low, INTC)        2264 non-null   float64
#  15  (Low, MCD)         2264 non-null   float64
#  16  (Low, PG)          2264 non-null   float64
#  17  (Low, WMT)         2264 non-null   float64
#  18  (Close, AXP)       2264 non-null   float64
#  19  (Close, FB)        1664 non-null   float64
#  20  (Close, INTC)      2264 non-null   float64
#  21  (Close, MCD)       2264 non-null   float64
#  22  (Close, PG)        2264 non-null   float64
#  23  (Close, WMT)       2264 non-null   float64
#  24  (Adj Close, AXP)   2264 non-null   float64
#  25  (Adj Close, FB)    1664 non-null   float64
#  26  (Adj Close, INTC)  2264 non-null   float64
#  27  (Adj Close, MCD)   2264 non-null   float64
#  28  (Adj Close, PG)    2264 non-null   float64
#  29  (Adj Close, WMT)   2264 non-null   float64
#  30  (Volume, AXP)      2264 non-null   int64
#  31  (Volume, FB)       1664 non-null   float64
#  32  (Volume, INTC)     2264 non-null   int64
#  33  (Volume, MCD)      2264 non-null   int64
#  34  (Volume, PG)       2264 non-null   int64
#  35  (Volume, WMT)      2264 non-null   int64
# dtypes: float64(31), int64(5)
# memory usage: 654.4 KB

# %%
stocks = stocks.loc["2015-12-31":"2019-01-01", "Adj Close"]

# %% [markdown]
# __Visualize__ the Adjusted Close of the six stocks __over time__!

# %%
plt.rcdefaults()

# %%
plt.figure(figsize= (15, 8))
sns.lineplot(stocks, dashes= False)
plt.show()

# %% [markdown]
# __Visualize__ the Adjusted Close of the six stocks __over time__, starting each at the __Base Value 100__!

# %%
norm_base_100 = stocks.div(stocks.iloc[0]).mul(100)
norm_base_100.head()
# Out:
#                    AXP          FB        INTC         MCD          PG  \
# Date
# 2015-12-31  100.000000  100.000000  100.000000  100.000000  100.000000
# 2016-01-04   97.181859   97.668639   98.664755   99.526001   98.690331
# 2016-01-05   95.686586   98.155933   98.200317  100.897243   99.005167
# 2016-01-06   93.029395   98.385245   96.023252  100.220084   98.048091
# 2016-01-07   92.191810   93.560094   92.423820   97.900822   97.191791
#
#                    WMT
# Date
# 2015-12-31  100.000000
# 2016-01-04  100.261012
# 2016-01-05  102.642742
# 2016-01-06  103.670463
# 2016-01-07  106.084838

# %%
plt.figure(figsize= (15, 8))
sns.lineplot(norm_base_100, dashes= False)
plt.title("norm_base_100")
plt.ylabel("% change")
plt.show()

# %% [markdown]
# Calculate __monthly returns__ for all six stocks and create a new __returns__ DataFrame!

# %%
returns_daily = stocks.pct_change().dropna()
returns_daily
# Out:
#                  AXP        FB      INTC       MCD        PG       WMT
# Date
# 2016-01-04 -0.028181 -0.023314 -0.013352 -0.004740 -0.013097  0.002610
# 2016-01-05 -0.015386  0.004989 -0.004707  0.013778  0.003190  0.023755
# 2016-01-06 -0.027770  0.002336 -0.022170 -0.006711 -0.009667  0.010013
# 2016-01-07 -0.009003 -0.049043 -0.037485 -0.023142 -0.008733  0.023289
# 2016-01-08 -0.003289 -0.006025 -0.010364 -0.001556 -0.015678 -0.022913
# ...              ...       ...       ...       ...       ...       ...
# 2018-12-21 -0.046361 -0.063343 -0.015371  0.002706 -0.000110 -0.001719
# 2018-12-24 -0.020037 -0.007123 -0.027877 -0.022222 -0.039683 -0.015035
# 2018-12-26  0.048492  0.081573  0.059647  0.022023  0.031250  0.053484
# 2018-12-27  0.008951  0.002534  0.003681  0.009654  0.021423  0.013052
# 2018-12-28 -0.002746 -0.009813  0.008412 -0.000854 -0.009128  0.005896
#
# [753 rows x 6 columns]

# %%
returns = stocks.resample("M", kind= "period").last().pct_change().dropna()#.mul(100).sub(1)
returns
# Out:
#               AXP        FB      INTC       MCD        PG       WMT
# Date
# 2016-01 -0.227403  0.072138 -0.099564  0.047740  0.037677  0.082545
# 2016-02  0.038879 -0.047144 -0.037703 -0.046067 -0.017138 -0.000302
# 2016-03  0.104714  0.067153  0.093275  0.072446  0.025159  0.040051
# 2016-04  0.070794  0.030500 -0.063988  0.006445 -0.018639 -0.023653
# 2016-05  0.005044  0.010461  0.052274 -0.035022  0.011483  0.066221
# 2016-06 -0.071383 -0.038128  0.038303 -0.006845  0.044793  0.031647
# 2016-07  0.060895  0.084529  0.062805 -0.022353  0.018781 -0.000685
# 2016-08  0.017375  0.017589  0.037351 -0.009274  0.020096 -0.014265
# 2016-09 -0.023483  0.017047  0.051825 -0.002594  0.027947  0.009518
# 2016-10  0.042384  0.021205 -0.076291 -0.024185 -0.025408 -0.029118
# 2016-11  0.084613 -0.095962  0.002659  0.067758 -0.050000  0.005855
# 2016-12  0.028318 -0.028458  0.045245  0.020542  0.019646 -0.011576
# 2017-01  0.035445  0.132725  0.015164  0.006983  0.050116 -0.034433
# 2017-02  0.048180  0.040055 -0.009820  0.049111  0.039612  0.062781
# 2017-03 -0.011866  0.048030 -0.003591  0.015354 -0.013396  0.023685
# 2017-04  0.005883  0.057726  0.002218  0.079624 -0.020608  0.043008
# 2017-05 -0.029148  0.008053  0.006311  0.078325  0.008702  0.052487
# 2017-06  0.094879 -0.003169 -0.065633  0.021407 -0.010671 -0.037150
# 2017-07  0.015571  0.121009  0.051274  0.012928  0.050282  0.056950
# 2017-08  0.010207  0.016071 -0.003869  0.037251  0.015966 -0.017864
# 2017-09  0.050639 -0.006396  0.085828 -0.020566 -0.013981  0.000897
# 2017-10  0.060013  0.053784  0.194590  0.065292 -0.043893  0.117353
# 2017-11  0.022927 -0.015995 -0.008458  0.036458  0.042275  0.113618
# 2017-12  0.016375 -0.004064  0.029438  0.000872  0.021002  0.020986
# 2018-01  0.004438  0.059107  0.042894 -0.005694 -0.053136  0.079494
# 2018-02 -0.019014 -0.045856  0.030835 -0.072468 -0.090572 -0.155629
# 2018-03 -0.043380 -0.103914  0.056604 -0.008622  0.009679 -0.005661
# 2018-04  0.062615  0.076413 -0.008833  0.070725 -0.079092 -0.005732
# 2018-05 -0.004557  0.115000  0.075525 -0.044374  0.011474 -0.061045
# 2018-06 -0.003052  0.013244 -0.099456 -0.014528  0.066831  0.037679
# 2018-07  0.019156 -0.111877 -0.032388  0.005425  0.045532  0.041798
# 2018-08  0.064912  0.018252  0.012984  0.036199  0.025594  0.080542
# 2018-09  0.004812 -0.064132 -0.023539  0.031190  0.003376 -0.020342
# 2018-10 -0.031827 -0.077040 -0.008670  0.057445  0.074899  0.067831
# 2018-11  0.092865 -0.073654  0.058454  0.072202  0.065742 -0.026227
# 2018-12 -0.158992 -0.052699 -0.051916 -0.068697 -0.035234 -0.051380

# %% [markdown]
# Calculate the __annualized mean return__ and the __annualized standard deviation__ of returns for all six stocks!

# %%
#NUMBER_OF_MONTHS = len(returns.index.month)
NUMBER_OF_MONTHS = 12

# %%
ann_mean_return =  returns.mean() * NUMBER_OF_MONTHS
ann_mean_return.name = "Mean"
ann_mean_return
# Out:
# AXP     0.145942
# FB      0.103868
# INTC    0.150712
# MCD     0.170144
# PG      0.088297
# WMT     0.179962
# Name: Mean, dtype: float64

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
ann_std = returns.std() * np.sqrt(NUMBER_OF_MONTHS)
ann_std.name = "Std"
ann_std
# Out:
# AXP     0.226748
# FB      0.218871
# INTC    0.204255
# MCD     0.144859
# PG      0.138374
# WMT     0.187247
# Name: Std, dtype: float64

# %%
ret_vs_std = ann_mean_return.to_frame()
ret_vs_std["Std"] = ann_std

# %%
ret_vs_std
# Out:
#           Mean       Std
# AXP   0.145942  0.226748
# FB    0.103868  0.218871
# INTC  0.150712  0.204255
# MCD   0.170144  0.144859
# PG    0.088297  0.138374
# WMT   0.179962  0.187247

# %%
plt.figure(figsize= (12, 8))

for i in ret_vs_std.index:
    plt.annotate(i, xy= (ret_vs_std.loc[i, "Std"] + 0.001, ret_vs_std.loc[i, "Mean"] + 0.001))

sns.scatterplot(ret_vs_std , x= ret_vs_std["Std"], y = ret_vs_std["Mean"])
plt.title("Mean return VS Standart Deviation")
plt.show()

# %% [markdown]
# __Visualize risk/return__ of all six stocks in a (total) risk / return framework. (annualized std on the x-axis, annualized mean returns on the y-axis). <br>
# Identify the __best performing__ stock and the __worst performing__ stock (in terms of __risk / return__)

# %% [markdown]
# ## BEST --> MCD mean = 0.170144	std = 0.144859
# ## WORST --> FB mean = 0.103868	std = 0.218871

# %% [markdown]
# __Reindex__ the DataFrame __stocks__ with all __365 calander days of 2018__. Fill NaN Values!

# %%
all_days = pd.date_range(start = "2018-01-01", end= "2018-12-31", freq= "D")
all_days
# Out:
# DatetimeIndex(['2018-01-01', '2018-01-02', '2018-01-03', '2018-01-04',
#                '2018-01-05', '2018-01-06', '2018-01-07', '2018-01-08',
#                '2018-01-09', '2018-01-10',
#                ...
#                '2018-12-22', '2018-12-23', '2018-12-24', '2018-12-25',
#                '2018-12-26', '2018-12-27', '2018-12-28', '2018-12-29',
#                '2018-12-30', '2018-12-31'],
#               dtype='datetime64[ns]', length=365, freq='D')

# %%
stocks = stocks.reindex(all_days)
stocks = stocks.fillna(method= "ffill").dropna()

# %%
stocks
# Out:
#                   AXP          FB       INTC         MCD         PG        WMT
# 2018-01-02  97.122566  181.419998  45.412144  168.941528  86.876450  96.304199
# 2018-01-03  97.721367  184.669998  43.870941  168.229553  86.771019  97.144257
# 2018-01-04  99.346771  184.330002  43.066414  169.409668  87.384384  97.232178
# 2018-01-05  99.573341  186.850006  43.366901  169.751038  87.441887  97.808487
# 2018-01-06  99.573341  186.850006  43.366901  169.751038  87.441887  97.808487
# ...               ...         ...        ...         ...        ...        ...
# 2018-12-27  94.294075  134.520004  46.067993  175.710007  91.297897  91.589996
# 2018-12-28  94.035133  133.199997  46.455536  175.559998  90.464493  92.129997
# 2018-12-29  94.035133  133.199997  46.455536  175.559998  90.464493  92.129997
# 2018-12-30  94.035133  133.199997  46.455536  175.559998  90.464493  92.129997
# 2018-12-31  94.035133  133.199997  46.455536  175.559998  90.464493  92.129997
#
# [364 rows x 6 columns]

# %% [markdown]
# __Ticker Symbols__:
# - AXP : American Express
# - FB : Facebook
# - INTC : Intel
# - MCD : McDonalds
# - PG : Procter & Gamble
# - WMT: Walmart

# %% [markdown]
# ------------------------

# %% [markdown]
# ## Option 2: Guided and Instructed

# %% [markdown]
# # STOP HERE, IF YOU WANT TO DO THE EXERCISE ON YOUR OWN!

# %% [markdown]
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++

# %%
#run the cell!
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use("seaborn")

# %% [markdown]
# 154. __Import__ daily stock price data (__us_stocks.csv__) and __insepct__! Handle the __MultiIndex__! __Fill in the gaps__!

# %%
stocks = pd.read_csv(---, header = [---, ---], index_col= [---], parse_dates= [---])

# %%
# run the cell!
stocks.head()

# %% [markdown]
# Ticker Symbols:
# - AXP : American Express
# - FB : Facebook
# - INTC : Intel
# - MCD : McDonalds
# - PG : Procter & Gamble
# - WMT: Walmart

# %% [markdown]
# 155. __Select__ the Adjusted Close (__Adj Close__) for all six stocks from __31-12-2015__ (incl.) until __31-12-2018__ (incl.)! __Overwrite__ stocks! <br>
# __How many Timestamps__ / Days are now in the DataFrame?

# %%
# run the cell!
stocks.head()

# %%
# run the cell!
stocks.info()

# %% [markdown]
# We have ... 754 Days.

# %% [markdown]
# 156. __Plot__ stocks (figsize (12, 8)!

# %% [markdown]
# 157. __Bring__ the six stocks to the __same Base__ (100) and __plot__ again! __Fill in the gaps!__

# %%
stocks.---(stocks.iloc[0]).---(figsize = (12, 8))
plt.show()

# %% [markdown]
# Still hard to compare performance, right?

# %% [markdown]
# 158. __Resample__ stocks to __monthly__ frequency (__last__ trading price of each month)! __Save__ resampled Dataframe in the variable __stocks_m__!

# %%
# run the cell!
stocks_m.head()

# %% [markdown]
# 159. Calculate __monthly returns__ and __save__ the result in the variable __ret__! (drop NaN Values!)

# %%
#run the cell!
ret

# %% [markdown]
# 160. Calculate __mean__ and  __standard deviation__ of monthly returns! __Save__ the result in the variable __summary__!<br>
# __Fill in the gaps!__

# %%
summary = ret.---.T.iloc[:, [1,2]]

# %%
#run the cell!
summary

# %% [markdown]
# 161. __Annualize__ mean and standard deviation of returns! __Fill in the gaps!__

# %%
summary["mean"] = summary["mean"] * ---
summary["std"] = summary["std"] * ---

# %%
#run the cell!
summary

# %% [markdown]
# 162. __Plot__ and __compare__ the performance of the six stocks in a __(total) risk / return__ framework! __Fill in the gaps__! <br>
# Can you identify the __best performing__ stock and the __worst performing__ stock (in terms of __risk / return__)?

# %%
summary.plot(kind = ---, x = ---, y = ---, figsize = (12, 8), s = 50, fontsize = 15, xlim = (0.1, 0.3), ylim = (0, 0.25))
for i in summary.index:
    plt.annotate(i, xy=(summary.loc[i, "std"]+0.002, summary.loc[i, "mean"]+0.002), size = 15)
plt.xlabel("ann. Risk(std)", fontsize = 15)
plt.ylabel("ann. Return", fontsize = 15)
plt.title("Risk/Return", fontsize = 20)
plt.show()

# %% [markdown]
# In a (total) risk / return framework, McDonalds (most likely) showed the best performance and facebook the worst performance!

# %% [markdown]
# Next, let´s return a DataFrame with stock price information for __all 365 days__ in the year __2018__.

# %% [markdown]
# 163. First, create a __new DatetimeIndex__ (year_2018) with __all 365 days__/timestamps in the year __2018__!

# %%
# run the cell!
year_2018

# %%
# run the cell!
stocks.head()

# %% [markdown]
# 164. Second, __reindex__ the stocks DataFrame accordingly! Use the most appropriate __method__ to __fill NaNs__!

# %% [markdown]
# # Well Done!

# %% [markdown]
# -------------------

# %% [markdown]
# # Hints (Spoiler!)

# %% [markdown]
# 154. The first two rows (index pos. 0 & 1) form the Columns MultiIndex. The Column with Datetime information is at index pos. 0.

# %% [markdown]
# 155. stocks = stocks.loc["31-12-2015":"31-12-2018", "Adj Close"]

# %% [markdown]
# 156. plot() method

# %% [markdown]
# 157. div() method, plot() method

# %% [markdown]
# 158. resample() method, last() method, use "BM" (month end business day)

# %% [markdown]
# 159. pct_change() method, dropna() method

# %% [markdown]
# 160. describe() method

# %% [markdown]
# 161. *12 and *np.sqrt(12)

# %% [markdown]
# 162. scatterplot, std and mean

# %% [markdown]
# 163. pd.date_range() method

# %% [markdown]
# 164. reindex() method, ffill
